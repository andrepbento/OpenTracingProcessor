# %% [markdown]
# This experience aims to analyze data produced by PostOTP.
#
# This data is in csv format, and represents a counting of the type of flows for every field in every trace.
#
# Objectives:
#    - Map data to visual charts, etc.
#    - Produce histograms with the data.

# %%
import pandas as pd

# %%
import os

DATA_FOLDER = "/mnt/B6C8BAECC8BAAA4F/André/UC/Tese/Projects/jaime/OpenTracingProcessor/data/"

COMPLETE_DATA_FOLDER = os.path.join(DATA_FOLDER, "csv_maps_complete")
ANOMALOUS_DATA_FOLDER_1 = os.path.join(DATA_FOLDER, "csv_maps_anomalous_time_frame_28.06__14_25__14_35")
ANOMALOUS_DATA_FOLDER_2 = os.path.join(DATA_FOLDER, "csv_maps_anomalous_time_frame_28.06__16_25__16_35")
ANOMALOUS_DATA_FOLDER_3 = os.path.join(DATA_FOLDER, "csv_maps_anomalous_time_frame_28.06__20_25__20_35")
NON_ANOMALOUS_DATA_FOLDER_1 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__14_55__15_05")
NON_ANOMALOUS_DATA_FOLDER_2 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__15_05__15_15")
NON_ANOMALOUS_DATA_FOLDER_3 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__15_15__15_25")
NON_ANOMALOUS_DATA_FOLDER_4 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_29.06__07_15__07_25")

CSV_FILE = "flows_infos.csv"

#COMPLETE_DATA = pd.read_csv(os.path.join(COMPLETE_DATA_FOLDER, CSV_FILE))

ANOMALOUS_DATA_1 = pd.read_csv(os.path.join(ANOMALOUS_DATA_FOLDER_1, CSV_FILE))
ANOMALOUS_DATA_2 = pd.read_csv(os.path.join(ANOMALOUS_DATA_FOLDER_2, CSV_FILE))
ANOMALOUS_DATA_3 = pd.read_csv(os.path.join(ANOMALOUS_DATA_FOLDER_3, CSV_FILE))

NON_ANOMALOUS_DATA_1 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_1, CSV_FILE))
NON_ANOMALOUS_DATA_2 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_2, CSV_FILE))
NON_ANOMALOUS_DATA_3 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_3, CSV_FILE))
NON_ANOMALOUS_DATA_4 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_4, CSV_FILE))

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

def plot_dataframe(df, title):
    objects = df['flow_type']
    y_pos = np.arange(len(objects))
    performance = df['count']

    plt.bar(y_pos, performance, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.xlabel('Flow type')
    plt.ylabel('Count')
    plt.title(title)

    plt.show()

# %%
ANOMALOUS_DATA_1.sort_values(by=['count'], ascending=False)

#ANOMALOUS_DATA_1.info()
# Out:
#                                                  flow  count  duration  \
# 16  {"spanValue":"209.128.139.87","spanChildren":[...    153    530880
# 13  {"spanValue":"146.121.59.106","spanChildren":[...    149    518513
# 20  {"spanValue":"197.80.188.246","spanChildren":[...    129    504730
# 4                      {"spanValue":"146.121.59.106"}     76    484617
# 11                     {"spanValue":"209.128.139.87"}     59    217547
# 26                     {"spanValue":"197.80.188.246"}     57    197710
# 2   {"spanValue":"209.128.139.87","spanChildren":[...     37    443026
# 25  {"spanValue":"146.121.59.106","spanChildren":[...     33    475399
# 27  {"spanValue":"197.80.188.246","spanChildren":[...     27    426482
# 6                      {"spanValue":"246.245.86.113"}      5     96789
# 7   {"spanValue":"197.80.188.246","spanChildren":[...      5    405654
# 3   {"spanValue":"209.128.139.87","spanChildren":[...      4    463665
# 24                       {"spanValue":"86.3.216.183"}      4      8708
# 8                                  {"spanValue":null}      3     24901
# 12  {"spanValue":"146.121.59.106","spanChildren":[...      3    454118
# 17  {"spanValue":"197.80.188.246","spanChildren":[...      3    450369
# 14  {"spanValue":"197.80.188.246","spanChildren":[...      2    187967
# 22  {"spanValue":"209.128.139.87","spanChildren":[...      2    408331
# 21  {"spanValue":"93.152.115.248","spanChildren":[...      2     13440
# 28  {"spanValue":"146.121.59.106","spanChildren":[...      2    482041
# 19  {"spanValue":"209.128.139.87","spanChildren":[...      2    384142
# 9   {"spanValue":null,"spanChildren":[{"0":"{\"spa...      2    236115
# 18  {"spanValue":"209.128.139.87","spanChildren":[...      1    351925
# 15  {"spanValue":"146.121.59.106","spanChildren":[...      1    165899
# 23  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      1    464690
# 1   {"spanValue":"146.121.59.106","spanChildren":[...      1    211364
# 10  {"spanValue":"93.152.115.248","spanChildren":[...      1     27822
# 5   {"spanValue":"146.121.59.106","spanChildren":[...      1    415874
# 0   {"spanValue":"146.121.59.106","spanChildren":[...      1    217081
#
#                                   most_expensive_path  most_expensive_duration
# 16                               209.128.139.87->null                   526587
# 13                               146.121.59.106->null                   357129
# 20                               197.80.188.246->null                   670479
# 4                                      146.121.59.106                    12976
# 11                                     209.128.139.87                    13143
# 26                                     197.80.188.246                    23125
# 2   209.128.139.87->null->255.24.137.124->255.24.1...                   641258
# 25  146.121.59.106->null->255.24.137.124->255.24.1...                  1597393
# 27  197.80.188.246->null->255.24.137.124->255.24.1...                   633363
# 6                                      246.245.86.113                    96789
# 7   197.80.188.246->null->255.24.137.124->255.24.1...                  1134049
# 3                                209.128.139.87->null                   853905
# 24                                       86.3.216.183                     8285
# 8                                                 NaN                    15633
# 12                               146.121.59.106->null                   662310
# 17                               197.80.188.246->null                   836375
# 14  197.80.188.246->null->255.24.137.124->255.24.1...                   511011
# 22  209.128.139.87->null->255.24.137.124->255.24.1...                  1144469
# 21                               93.152.115.248->null                     9203
# 28  146.121.59.106->null->255.24.137.124->255.24.1...                  1503963
# 19  209.128.139.87->null->null->255.24.137.124->25...                   661326
# 9   null->null->255.24.137.124->255.24.137.124->25...                   693872
# 18  209.128.139.87->null->255.24.137.124->255.24.1...                  1147441
# 15               146.121.59.106->null->255.24.137.124                   320197
# 23                                         null->null                   857573
# 1   146.121.59.106->null->255.24.137.124->255.24.1...                   574066
# 10                               93.152.115.248->null                    48302
# 5   146.121.59.106->null->255.24.137.124->255.24.1...                  1232580
# 0                                146.121.59.106->null                   326854

# %%
ANOMALOUS_DATA_2.sort_values(by=['count'], ascending=False)

#ANOMALOUS_DATA_2.info()
# Out:
#                                                  flow  count  duration  \
# 1   {"spanValue":"146.121.59.106","spanChildren":[...    125    490778
# 4   {"spanValue":"209.128.139.87","spanChildren":[...    121    474052
# 9   {"spanValue":"197.80.188.246","spanChildren":[...    121    477288
# 21                     {"spanValue":"209.128.139.87"}     55     98166
# 8                      {"spanValue":"146.121.59.106"}     53    103603
# 16                     {"spanValue":"197.80.188.246"}     45    145095
# 15  {"spanValue":"197.80.188.246","spanChildren":[...     34    453091
# 5   {"spanValue":"209.128.139.87","spanChildren":[...     29    454063
# 14  {"spanValue":"146.121.59.106","spanChildren":[...     19    367045
# 10  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      5    356249
# 12                       {"spanValue":"86.3.216.183"}      4     44631
# 18  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      2    303651
# 11                     {"spanValue":"246.245.86.113"}      2     72773
# 7   {"spanValue":"209.128.139.87","spanChildren":[...      2    434068
# 13  {"spanValue":"197.80.188.246","spanChildren":[...      1    442282
# 6   {"spanValue":"197.80.188.246","spanChildren":[...      1    451988
# 3   {"spanValue":"197.80.188.246","spanChildren":[...      1    246211
# 17                                 {"spanValue":null}      1     15482
# 2   {"spanValue":"209.128.139.87","spanChildren":[...      1    195752
# 19  {"spanValue":"209.128.139.87","spanChildren":[...      1    416354
# 20  {"spanValue":"146.121.59.106","spanChildren":[...      1    451985
# 0   {"spanValue":"146.121.59.106","spanChildren":[...      1    228213
#
#                                   most_expensive_path  most_expensive_duration
# 1                                146.121.59.106->null                   457503
# 4                                209.128.139.87->null                   386180
# 9                                197.80.188.246->null                   336439
# 21                                     209.128.139.87                    17181
# 8                                      146.121.59.106                    14689
# 16                                     197.80.188.246                    13596
# 15  197.80.188.246->null->255.24.137.124->255.24.1...                   644983
# 5   209.128.139.87->null->255.24.137.124->255.24.1...                   585929
# 14  146.121.59.106->null->255.24.137.124->255.24.1...                   736683
# 10                                         null->null                   523934
# 12                                       86.3.216.183                    44631
# 18  null->null->255.24.137.124->255.24.137.124->25...                   536358
# 11                                     246.245.86.113                    15650
# 7                                209.128.139.87->null                   791337
# 13  197.80.188.246->null->255.24.137.124->255.24.1...                  1358861
# 6                                197.80.188.246->null                   810866
# 3   197.80.188.246->null->255.24.137.124->null->25...                   710307
# 17                                                NaN                    15482
# 2   209.128.139.87->null->255.24.137.124->255.24.1...                   511032
# 19  209.128.139.87->null->255.24.137.124->255.24.1...                  1295934
# 20  146.121.59.106->null->255.24.137.124->255.24.1...                  1291605
# 0                                146.121.59.106->null                   353592

# %%
ANOMALOUS_DATA_3.sort_values(by=['count'], ascending=False)

#ANOMALOUS_DATA_3.info()
# Out:
#                                                  flow  count  duration  \
# 9   {"spanValue":"197.80.188.246","spanChildren":[...    141    402874
# 5   {"spanValue":"209.128.139.87","spanChildren":[...    115    418252
# 2   {"spanValue":"146.121.59.106","spanChildren":[...    105    414746
# 19  {"spanValue":"197.80.188.246","spanChildren":[...     30    396701
# 6   {"spanValue":"209.128.139.87","spanChildren":[...     30    358250
# 17  {"spanValue":"146.121.59.106","spanChildren":[...     23    380089
# 21                     {"spanValue":"209.128.139.87"}     10     58772
# 10                     {"spanValue":"146.121.59.106"}      6    341883
# 18                     {"spanValue":"197.80.188.246"}      4     15718
# 14  {"spanValue":"146.121.59.106","spanChildren":[...      1    225289
# 20  {"spanValue":"146.121.59.106","spanChildren":[...      1    378176
# 16  {"spanValue":"197.80.188.246","spanChildren":[...      1    356740
# 15                       {"spanValue":"86.3.216.183"}      1      8916
# 0   {"spanValue":"146.121.59.106","spanChildren":[...      1    204555
# 13  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      1    348611
# 12  {"spanValue":"209.128.139.87","spanChildren":[...      1    358922
# 1   {"spanValue":"146.121.59.106","spanChildren":[...      1    243926
# 8   {"spanValue":"209.128.139.87","spanChildren":[...      1    208900
# 7   {"spanValue":"197.80.188.246","spanChildren":[...      1    366060
# 4   {"spanValue":"209.128.139.87","spanChildren":[...      1    196133
# 3   {"spanValue":"209.128.139.87","spanChildren":[...      1    218394
# 11  {"spanValue":"146.121.59.106","spanChildren":[...      1    378973
#
#                                   most_expensive_path  most_expensive_duration
# 9                                197.80.188.246->null                   345707
# 5                                209.128.139.87->null                   371688
# 2                                146.121.59.106->null                   435479
# 19  197.80.188.246->null->255.24.137.124->255.24.1...                   825276
# 6   209.128.139.87->null->255.24.137.124->255.24.1...                   524428
# 17  146.121.59.106->null->255.24.137.124->255.24.1...                   850022
# 21                                     209.128.139.87                    58772
# 10                                     146.121.59.106                    12476
# 18                                     197.80.188.246                    14854
# 14  146.121.59.106->null->255.24.137.124->null->25...                   611081
# 20  146.121.59.106->null->255.24.137.124->255.24.1...                  1106529
# 16  197.80.188.246->null->255.24.137.124->255.24.1...                  1052425
# 15                                       86.3.216.183                     8916
# 0                146.121.59.106->null->255.24.137.124                   402131
# 13                                         null->null                   508981
# 12  209.128.139.87->null->255.24.137.124->255.24.1...                  1082242
# 1                                146.121.59.106->null                   387298
# 8   209.128.139.87->null->null->255.24.137.124->25...                   539977
# 7                                197.80.188.246->null                   664274
# 4   209.128.139.87->null->255.24.137.124->255.24.1...                   528699
# 3   209.128.139.87->null->255.24.137.124->null->25...                   593128
# 11  146.121.59.106->null->255.24.137.124->255.24.1...                  1178912

# %%
NON_ANOMALOUS_DATA_1.sort_values(by=['count'], ascending=False)

#NON_ANOMALOUS_DATA_1.info()
# Out:
#                                                  flow  count  duration  \
# 20  {"spanValue":"197.80.188.246","spanChildren":[...    119    487739
# 14  {"spanValue":"146.121.59.106","spanChildren":[...    118    479884
# 17  {"spanValue":"209.128.139.87","spanChildren":[...    116    514001
# 11                     {"spanValue":"209.128.139.87"}     91    117837
# 26                     {"spanValue":"197.80.188.246"}     87    355896
# 5                      {"spanValue":"146.121.59.106"}     83     76366
# 25  {"spanValue":"146.121.59.106","spanChildren":[...     18    424264
# 27  {"spanValue":"197.80.188.246","spanChildren":[...     16    282875
# 4   {"spanValue":"209.128.139.87","spanChildren":[...     15    275519
# 16  {"spanValue":"209.128.139.87","spanChildren":[...      4    401326
# 22  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      3    277997
# 15  {"spanValue":"197.80.188.246","spanChildren":[...      2    257839
# 24  {"spanValue":"209.128.139.87","spanChildren":[...      2    402782
# 0   {"spanValue":"146.121.59.106","spanChildren":[...      2    341274
# 9   {"spanValue":"93.152.115.248","spanChildren":[...      2     25899
# 7   {"spanValue":"197.80.188.246","spanChildren":[...      2    356855
# 3   {"spanValue":"197.80.188.246","spanChildren":[...      2    236559
# 2   {"spanValue":"197.80.188.246","spanChildren":[...      2    362926
# 1   {"spanValue":"209.128.139.87","spanChildren":[...      1    188256
# 13  {"spanValue":"146.121.59.106","spanChildren":[...      1    223771
# 12  {"spanValue":"146.121.59.106","spanChildren":[...      1    480973
# 10  {"spanValue":null,"spanChildren":[{"0":"{\"spa...      1    191497
# 18  {"spanValue":"197.80.188.246","spanChildren":[...      1    386559
# 19  {"spanValue":"209.128.139.87","spanChildren":[...      1    231673
# 21  {"spanValue":"209.128.139.87","spanChildren":[...      1    433235
# 8                                  {"spanValue":null}      1     12324
# 23  {"spanValue":"146.121.59.106","spanChildren":[...      1    191844
# 6                      {"spanValue":"246.245.86.113"}      1      9611
# 28  {"spanValue":"197.80.188.246","spanChildren":[...      1    361754
#
#                                   most_expensive_path  most_expensive_duration
# 20                               197.80.188.246->null                   378153
# 14                               146.121.59.106->null                   305995
# 17                               209.128.139.87->null                   332253
# 11                                     209.128.139.87                    14340
# 26                                     197.80.188.246                    11272
# 5                                      146.121.59.106                    13509
# 25  146.121.59.106->null->255.24.137.124->255.24.1...                   548810
# 27  197.80.188.246->null->255.24.137.124->255.24.1...                   526424
# 4   209.128.139.87->null->255.24.137.124->255.24.1...                   655903
# 16                               209.128.139.87->null                   462585
# 22                                         null->null                   492776
# 15               197.80.188.246->null->255.24.137.124                   456686
# 24                               209.128.139.87->null                   607702
# 0                                146.121.59.106->null                   471704
# 9                                93.152.115.248->null                    27878
# 7   197.80.188.246->null->255.24.137.124->255.24.1...                  1053660
# 3   197.80.188.246->null->255.24.137.124->null->25...                   648909
# 2                                197.80.188.246->null                   485150
# 1   209.128.139.87->null->255.24.137.124->255.24.1...                   516188
# 13               146.121.59.106->null->255.24.137.124                   389855
# 12                               146.121.59.106->null                   899525
# 10  null->null->255.24.137.124->255.24.137.124->25...                   530597
# 18                               197.80.188.246->null                   703344
# 19  209.128.139.87->null->null->255.24.137.124->25...                   579354
# 21  209.128.139.87->null->255.24.137.124->255.24.1...                  1273747
# 8                                                 NaN                    12324
# 23  146.121.59.106->null->255.24.137.124->null->25...                   533920
# 6                                      246.245.86.113                     9611
# 28  197.80.188.246->null->255.24.137.124->null->25...                  1060924

# %%
NON_ANOMALOUS_DATA_2.sort_values(by=['count'], ascending=False)

#NON_ANOMALOUS_DATA_2.info()
# Out:
#                                                 flow  count  duration  \
# 3                     {"spanValue":"146.121.59.106"}     45     87091
# 4                     {"spanValue":"209.128.139.87"}     45     31143
# 1                     {"spanValue":"197.80.188.246"}     42     95289
# 0                     {"spanValue":"246.245.86.113"}      1     40056
# 2  {"spanValue":"209.128.139.87","spanChildren":[...      1    181331
#
#                                  most_expensive_path  most_expensive_duration
# 3                                     146.121.59.106                    13026
# 4                                     209.128.139.87                    16991
# 1                                     197.80.188.246                    14364
# 0                                     246.245.86.113                    40056
# 2  209.128.139.87->null->255.24.137.124->255.24.1...                   481542

# %%
NON_ANOMALOUS_DATA_3.sort_values(by=['count'], ascending=False)

#NON_ANOMALOUS_DATA_3.info()
# Out:
#                                                  flow  count  duration  \
# 0   {"spanValue":"146.121.59.106","spanChildren":[...     48    240807
# 1   {"spanValue":"209.128.139.87","spanChildren":[...     47    232828
# 3   {"spanValue":"197.80.188.246","spanChildren":[...     45    237458
# 11                     {"spanValue":"209.128.139.87"}     37    223457
# 4                      {"spanValue":"146.121.59.106"}     34     30708
# 9                      {"spanValue":"197.80.188.246"}     32     62812
# 8   {"spanValue":"146.121.59.106","spanChildren":[...     17    222374
# 10  {"spanValue":"197.80.188.246","spanChildren":[...     14    231482
# 2   {"spanValue":"209.128.139.87","spanChildren":[...     10    228999
# 7                        {"spanValue":"86.3.216.183"}      5     82100
# 5                      {"spanValue":"246.245.86.113"}      3     13131
# 6   {"spanValue":null,"spanChildren":[{"0":"{\"spa...      1    218460
#
#                                   most_expensive_path  most_expensive_duration
# 0                                146.121.59.106->null                   357962
# 1                                209.128.139.87->null                   348715
# 3                                197.80.188.246->null                   344785
# 11                                     209.128.139.87                    14094
# 4                                      146.121.59.106                    13019
# 9                                      197.80.188.246                    11787
# 8   146.121.59.106->null->255.24.137.124->255.24.1...                   526641
# 10  197.80.188.246->null->255.24.137.124->255.24.1...                   512767
# 2   209.128.139.87->null->255.24.137.124->255.24.1...                   526947
# 7                                        86.3.216.183                    19651
# 5                                      246.245.86.113                     9800
# 6                                          null->null                   376423

# %%
NON_ANOMALOUS_DATA_4.sort_values(by=['count'], ascending=False)

#NON_ANOMALOUS_DATA_4.info()
# Out:
#                                                  flow  count  duration  \
# 7                      {"spanValue":"146.121.59.106"}     93    166738
# 12                     {"spanValue":"197.80.188.246"}     89    144272
# 15                     {"spanValue":"209.128.139.87"}     84    211330
# 3   {"spanValue":"209.128.139.87","spanChildren":[...     34    578987
# 1   {"spanValue":"146.121.59.106","spanChildren":[...     33    532722
# 6   {"spanValue":"197.80.188.246","spanChildren":[...     30    543234
# 10                       {"spanValue":"86.3.216.183"}     25    114235
# 8                      {"spanValue":"246.245.86.113"}     20     48192
# 4   {"spanValue":"209.128.139.87","spanChildren":[...      9    225958
# 14                                 {"spanValue":null}      7    137257
# 11  {"spanValue":"146.121.59.106","spanChildren":[...      5    442487
# 13  {"spanValue":"197.80.188.246","spanChildren":[...      5    545955
# 0   {"spanValue":"146.121.59.106","spanChildren":[...      1    295927
# 2   {"spanValue":"209.128.139.87","spanChildren":[...      1    393011
# 5   {"spanValue":"146.121.59.106","spanChildren":[...      1    188051
# 9   {"spanValue":null,"spanChildren":[{"0":"{\"spa...      1    178043
#
#                                   most_expensive_path  most_expensive_duration
# 7                                      146.121.59.106                    17643
# 12                                     197.80.188.246                    18068
# 15                                     209.128.139.87                    19888
# 3                                209.128.139.87->null                   339152
# 1                                146.121.59.106->null                   411557
# 6                                197.80.188.246->null                   338459
# 10                                       86.3.216.183                     8508
# 8                                      246.245.86.113                     6122
# 4   209.128.139.87->null->255.24.137.124->255.24.1...                   546616
# 14                                                NaN                    14602
# 11  146.121.59.106->null->255.24.137.124->255.24.1...                   518775
# 13  197.80.188.246->null->255.24.137.124->255.24.1...                   576206
# 0                                146.121.59.106->null                   478222
# 2                                209.128.139.87->null                   648795
# 5   146.121.59.106->null->null->255.24.137.124->25...                   528246
# 9                                          null->null                   297541

# %%
import itertools

# COMPLETE_DATA.info()
# ANOMALOUS_DATA.info()
# NON_ANOMALOUS_DATA.info()

flow_type_value_set = set(itertools.chain(COMPLETE_DATA['value'], 
                                          ANOMALOUS_DATA_1['value'], 
                                          ANOMALOUS_DATA_2['value'], 
                                          NON_ANOMALOUS_DATA_1['value'],
                                          NON_ANOMALOUS_DATA_2['value'],
                                          NON_ANOMALOUS_DATA_3['value']))

flow_df = pd.DataFrame(flow_type_value_set, columns=['value'])

def flow_indexes(df):
    indexes = list()
    for value in df['value']:
        index = flow_df.loc[flow_df['value'] == value].index.values[0]
        indexes.append(index)
        print('value:', value, 'index:', index)
    return indexes

COMPLETE_DATA['flow_type'] = flow_indexes(COMPLETE_DATA)
ANOMALOUS_DATA_1['flow_type'] = flow_indexes(ANOMALOUS_DATA_1)
ANOMALOUS_DATA_2['flow_type'] = flow_indexes(ANOMALOUS_DATA_2)
NON_ANOMALOUS_DATA_1['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_1)
NON_ANOMALOUS_DATA_2['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_2)
NON_ANOMALOUS_DATA_3['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_3)
    
# print(COMPLETE_DATA)
# print(ANOMALOUS_DATA)
# print(NON_ANOMALOUS_DATA_1)
# print(NON_ANOMALOUS_DATA_2)
# print(NON_ANOMALOUS_DATA_3)

# %% [markdown]
# ### Filter data
#
# In this section, we filter all data by the set of flow types presented in the anomalous and non anomalous data.

# %%
flow_type_index_set = set(itertools.chain(ANOMALOUS_DATA_1['flow_type'], 
                                          ANOMALOUS_DATA_2['flow_type'],
                                          NON_ANOMALOUS_DATA_1['flow_type'],
                                          NON_ANOMALOUS_DATA_2['flow_type'],
                                          NON_ANOMALOUS_DATA_3['flow_type']))

flow_type_index_set = sorted(flow_type_index_set)

FILTERED_COMPLETE_DATA = COMPLETE_DATA[COMPLETE_DATA['flow_type'].isin(flow_type_index_set)]
FILTERED_ANOMALOUS_DATA_1 = ANOMALOUS_DATA_1[ANOMALOUS_DATA_1['flow_type'].isin(flow_type_index_set)]
FILTERED_ANOMALOUS_DATA_2 = ANOMALOUS_DATA_2[ANOMALOUS_DATA_2['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_1 = NON_ANOMALOUS_DATA_1[NON_ANOMALOUS_DATA_1['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_2 = NON_ANOMALOUS_DATA_2[NON_ANOMALOUS_DATA_2['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_3 = NON_ANOMALOUS_DATA_3[NON_ANOMALOUS_DATA_3['flow_type'].isin(flow_type_index_set)]

# %% [markdown]
# ### Plot data
#
# Bellow are presented the plots for the completed time frame and some samples of anomalous and non anomalous time frames.
#
# All data is filtered by a set of anomalous and non anomalous flow types. In this way we focus on the specific flows that represent more interest for this analysis.

# %%
plot_dataframe(FILTERED_COMPLETE_DATA, 'Complete data')
plot_dataframe(FILTERED_ANOMALOUS_DATA_1, 'Anomalous data - Sample 1')
plot_dataframe(FILTERED_ANOMALOUS_DATA_2, 'Anomalous data - Sample 2')
#plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_1, 'Non anomalous data - Sample 1')
plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_2, 'Non anomalous data - Sample 1')
plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_3, 'Non anomalous data - Sample 2')
